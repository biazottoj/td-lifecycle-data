# %%
import pandas as pd
import os
import random

# %%
#Analyzing issues already classified
manually_issues_df = pd.read_csv('../manually-analyze-issues.csv')
issues_number = set([f"{manually_issues_df['project'][i].lower()}-{manually_issues_df['issue_number'][i]}" for i in manually_issues_df.index])

# %%
issues_df = pd.read_csv('issues-dataset.csv')
available_issues = list(set([f"{issues_df['project'][i]}-{issues_df['issue_number'][i]}" 
                        for i in issues_df.index 
                        if issues_df['classification'][i] != "non_debt" 
                        and issues_df['classification'][i] != "documentation_debt" 
                       and f"{issues_df['project'][i]}-{issues_df['issue_number'][i]}" not in issues_number]))



indexes = set([random.randint(0, len(available_issues) - 1) for i in range(100)])



print(len(indexes))

print(indexes)
for i in indexes:
    print(available_issues[i])
# Out:
# 97
# {4, 517, 7, 520, 1034, 14, 529, 530, 21, 539, 35, 550, 40, 1064, 1068, 50, 1077, 55, 569, 1086, 1087, 1088, 62, 579, 1091, 68, 1095, 1096, 592, 605, 615, 108, 123, 131, 651, 654, 657, 659, 665, 670, 165, 171, 685, 178, 700, 704, 705, 199, 200, 721, 724, 726, 216, 220, 236, 240, 761, 768, 267, 803, 297, 306, 819, 311, 329, 862, 353, 868, 870, 358, 362, 367, 372, 373, 887, 384, 385, 907, 401, 920, 931, 427, 451, 455, 457, 465, 984, 472, 474, 473, 479, 993, 484, 997, 488, 492, 1011}
# hbase-4311
# thrift-3168
# hadoop-15486
# hadoop-5402
# hbase-4088
# hbase-9901
# hbase-9303
# hadoop-4997
# hbase-274
# impala-2290
# hadoop-15066
# hadoop-758
# impala-4871
# hadoop-3999
# hadoop-9419
# hbase-11352
# hadoop-14942
# hbase-9493
# impala-5849
# camel-872
# hadoop-9309
# hadoop-6297
# hbase-19775
# impala-3252
# hadoop-16435
# thrift-4321
# hbase-19633
# hadoop-6198
# camel-1863
# hbase-23792
# impala-6937
# thrift-2006
# hadoop-5097
# thrift-717
# thrift-452
# hbase-19969
# impala-1984
# impala-3859
# hbase-11293
# hadoop-4634
# hbase-17325
# hbase-16789
# hbase-11612
# thrift-2791
# hbase-23061
# hbase-17394
# thrift-427
# hadoop-15859
# hadoop-2851
# hadoop-12371
# hadoop-1072
# hadoop-7684
# hadoop-11880
# hbase-8527
# thrift-2666
# hadoop-6869
# hbase-9433
# hbase-4341
# hbase-13871
# hadoop-7974
# hbase-8026
# hbase-10115
# hadoop-98
# impala-7688
# hbase-22981
# hbase-6184
# impala-4833
# hadoop-11309
# hadoop-4436
# hadoop-6279
# hbase-12846
# hbase-16273
# hbase-9340
# camel-4007
# hadoop-11355
# hbase-8103
# impala-4612
# hadoop-4300
# thrift-653
# hadoop-5701
# thrift-4443
# camel-11504
# impala-8771
# hadoop-6364
# thrift-4069
# hadoop-9655
# hbase-3807
# camel-3709
# hbase-8193
# hadoop-1961
# thrift-48
# hbase-21160
# hadoop-7161
# thrift-2431
# hbase-15397
# hadoop-5891
# hadoop-3286

# %%
# Extracting Classifications
#old = pd.read_csv('../manually-analyze-issues.csv')
#classifications = set([old['classification'][i] 
                        #for i in old.index 
                        #if old['classification'][i] != "non_debt"])
classification = ['Architecture-VioMod', 
                  'Architecture-ObsTech', 
                  'Code-SlAlg', 
                  'Code-DupCd', 
                  'Code-DedCd', 
                  'Code-MTCor', 
                  'Code-Oth', 
                  'Code-CpxCd', 
                  'Code-LQualCd', 
                  'Design-Des',
                  'Test-LacTst', 
                  'Test-ExpTst', 
                  'Test-LCvg', 
                  'Test-FlakyTst']
# Out:
# {'Test-LacTst', 'Test-ExpTst', 'Code-SlAlg', 'Test-LCvg', 'Test-FlakyTst', 'Code-DupCd', 'Code-DedCd', 'Code-MTCor', 'Code-Oth', 'Code-CpxCd', 'Architecture-VioMod', 'Code-LQualCd', 'Design-Des', 'Architecture-ObsTech'}

# %%
#Creating CSV
if 'td_items.csv' not in os.listdir():
    tdItems = ['td_item','classification','project','issue_number','issue_type','text', 'if_fixed', 'fixed_commit_hash','introduced_commit_hash']
    tdItems_df = pd.DataFrame(columns=tdItems)
    tdItems_df.to_csv('td_items.csv', index = False)
    
tdItems_df = pd.read_csv('td_items.csv')

issues_df = pd.read_csv('issues-dataset.csv')

# %%
project_issue = 'camel-1173'.split('-')
print(project_issue)
a = issues_df.loc[(issues_df['project'] == project_issue[0]) & (issues_df['issue_number'] == int(project_issue[1])) & (issues_df['classification'] != 'non_debt')]


for i in a.index:
    print(a['issue_number'][i])
    print(f"{a['classification'][i]} - {a['indicator'][i]}")
    print(a['text'][i])
    print(a['fixed_commit'][i])
    print('----')
# Out:
# ['camel', '1173']
# 1173
# documentation_debt - low_quality_documentation
# Adding Transmitting file data . Committed revision 724833. This is my first stab at the pattern. Not completely happy with it at the moment... maybe we need to put better support into Camel somewhere for this kinda thing.
# 1ee86d6e60cb0e91b881919f7d3a267eba16282c,f6cbe6529a1084383b72c06ab215a28dee3ebed7,7afe11b51a14e9b8723dddefb73b8038b220feb7
# ----
# 1173
# code_debt - low_quality_code
# Put in an improved scatter-gather example in revision 740056. The problem with the first example was that it was not dynamic enough. Also added wiki docs here
# 1ee86d6e60cb0e91b881919f7d3a267eba16282c,f6cbe6529a1084383b72c06ab215a28dee3ebed7,7afe11b51a14e9b8723dddefb73b8038b220feb7
# ----
# 1173
# documentation_debt - low_quality_documentation
# See We should be able to do this in Camel already... just need to cook up an example/doco for it.
# 1ee86d6e60cb0e91b881919f7d3a267eba16282c,f6cbe6529a1084383b72c06ab215a28dee3ebed7,7afe11b51a14e9b8723dddefb73b8038b220feb7
# ----
# 1173
# documentation_debt - low_quality_documentation
# Need example of scatter-gather pattern
# 1ee86d6e60cb0e91b881919f7d3a267eba16282c,f6cbe6529a1084383b72c06ab215a28dee3ebed7,7afe11b51a14e9b8723dddefb73b8038b220feb7
# ----

# %%
#['td_item','classification','project','issue_number','issue_type','text', 'if_fixed', 'fixed_commit_hash','introduced_commit_hash']

new_df = pd.read_csv('td-items.csv')
new_Items = []

for i in a.index:
    new_Items.append([f"{a['project'][i].upper()}-{a['issue_number'][i]}|0",
                     'Code-LQualCd',
                      a['project'][i],
                      a['issue_number'][i],
                      a['issue_type'][i],
                      f'"{a["text"][i]}"',
                      'yes',
                      'f6cbe6529a1084383b72c06ab215a28dee3ebed7',
                      '-'
                     ])

print(str(new_Items).replace("'","").replace(", ",","))
# Out:
# [[CAMEL-1173|0,Code-LQualCd,camel,1173,comment_0,"Adding Transmitting file data . Committed revision 724833. This is my first stab at the pattern. Not completely happy with it at the moment... maybe we need to put better support into Camel somewhere for this kinda thing.",yes,f6cbe6529a1084383b72c06ab215a28dee3ebed7,-],[CAMEL-1173|0,Code-LQualCd,camel,1173,comment_1,"Put in an improved scatter-gather example in revision 740056. The problem with the first example was that it was not dynamic enough. Also added wiki docs here",yes,f6cbe6529a1084383b72c06ab215a28dee3ebed7,-],[CAMEL-1173|0,Code-LQualCd,camel,1173,description,"See We should be able to do this in Camel already... just need to cook up an example/doco for it.",yes,f6cbe6529a1084383b72c06ab215a28dee3ebed7,-],[CAMEL-1173|0,Code-LQualCd,camel,1173,summary,"Need example of scatter-gather pattern",yes,f6cbe6529a1084383b72c06ab215a28dee3ebed7,-]]

# %%
new_df.to_csv('td-items.csv', index=False)

# %%
new_df = pd.read_csv('td-items.csv')
new_df.head(20)
# Out:
#           td_item classification project  issue_number   issue_type  \
# 0   HBASE-21160|0     Design-Des   hbase         21160    comment_1
# 1   HBASE-21160|0     Design-Des   hbase         21160    comment_2
# 2   HBASE-20975|0   Code-LQualCd   hbase         20975    comment_0
# 3   HBASE-20975|1      Test-LCvg   hbase         20975    comment_4
# 4   HBASE-20975|2     Design-Des   hbase         20975    comment_8
# 5   HBASE-20975|3     Code-MTCor   hbase         20975  description
# 6   THRIFT-4830|0     Code-SlAlg  thrift          4830  description
# 7   THRIFT-1745|0    Test-LacTst  thrift          1745    comment_0
# 8    CAMEL-8091|0     Design-Des   camel          8091  description
# 9   IMPALA-8005|0     Design-Des  impala          8005  description
# 10  CAMEL-11524|0   Code-LQualCd   camel         11524    comment_0
# 11  CAMEL-11524|0   Code-LQualCd   camel         11524    comment_1
# 12   CAMEL-1173|0   Code-LQualCd   camel          1173    comment_1
#
#                                                  text if_fixed  \
# 0   Since the catch block currently re-throws IOEx...      yes
# 1   Hi I found so many re-throws blocks in the fil...      yes
# 2   +1 on removing it for now. We have optimized t...      yes
# 3   Please include a small change in hbase-server ...       no
# 4   The failed UTs are related, upload a patch to ...      yes
# 5   Find this one when investigating HBASE-20921, ...      yes
# 6   ITNOA I think it useful and have some performa...      yes
# 7   Frederic,Thank you for your work on this. Woul...      yes
# 8   The does not consider the context property tha...      yes
# 9   Currently,we use the same hash seed for partit...      yes
# 10  No there is not,your workaround is to not use ...      yes
# 11  Hi Claus Thanks for the response. The source o...      yes
# 12  Put in an improved scatter-gather example in r...      yes
#
#                                     fixed_commit_hash introduced_commit_hash
# 0            1cf920db4395926c634ed0946a57dfa52227472f                      -
# 1            1cf920db4395926c634ed0946a57dfa52227472f                      -
# 2            a07e755625382d3904c935c21a4f240ede6d2f43                      -
# 3                                                   -                      -
# 4            a07e755625382d3904c935c21a4f240ede6d2f43                      -
# 5            a07e755625382d3904c935c21a4f240ede6d2f43                      -
# 6            6a61dfabbf6ae2fa9fbbc3996590ebdbe38e569f                      -
# 7   85fb6de7f4c1ea6260f98bc24401593e8c974bc7,05ab8...                      -
# 8            43d02628287c0623672714a016e324d6da36d71c                      -
# 9            df6196e064bc7453bee8c7e644bb591391ee3ce2                      -
# 10           1fa638ec156135ef9d5c6bb8684b81459c6c7c82                      -
# 11           1fa638ec156135ef9d5c6bb8684b81459c6c7c82                      -
# 12           f6cbe6529a1084383b72c06ab215a28dee3ebed7                      -
